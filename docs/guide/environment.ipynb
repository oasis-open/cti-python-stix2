# %%
# Delete this cell to re-enable tracebacks
import sys
ipython = get_ipython()

def hide_traceback(exc_tuple=None, filename=None, tb_offset=None,
                   exception_only=False, running_compiled_code=False):
    etype, value, tb = sys.exc_info()
    return ipython._showtraceback(etype, value, ipython.InteractiveTB.get_exception_only(etype, value))

ipython.showtraceback = hide_traceback

# %% [markdown]
# ## Using Environments
#
# An ``Environment`` object makes it easier to use STIX 2 content as part of a larger application or ecosystem. It allows you to abstract away the nasty details of sending and receiving STIX data, and to create STIX objects with default values for common properties.
#
# ### Storing and Retrieving STIX Content
#
# An ``Environment`` can be set up with a ``DataStore`` if you want to store and retrieve STIX content from the same place.

# %%
from stix2 import Environment, MemoryStore

env = Environment(store=MemoryStore())

# %% [markdown]
# If desired, you can instead set up an ``Environment`` with different data sources and sinks. In the following example we set up an environment that retrieves objects from memory and a directory on the filesystem, and stores objects in a different directory on the filesystem.

# %%
from stix2 import CompositeDataSource, FileSystemSink, FileSystemSource, MemorySource

src = CompositeDataSource()
src.add_data_source([MemorySource(), FileSystemSource("stix_source")])
env2 = Environment(source=src,
                   sink=FileSystemSink("stix_sink"))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-2-3626306f12b3> in <module>()
#       2
#       3 src = CompositeDataSource()
# ----> 4 src.add_data_source([MemorySource(), FileSystemSource("stix_source")])
#       5 env = Environment(source=src,
#       6                   sink=FileSystemSink("stix_sink"))
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in __init__(self, stix_dir)
#      63     def __init__(self, stix_dir="stix_data"):
#      64         super(FileSystemSource, self).__init__()
# ---> 65         self.stix_dir = os.path.abspath(stix_dir)
#      66
#      67         # check directory path exists
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
# ...
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/filesystem.pyc in stix_dir(self, dir)
#      75     @stix_dir.setter
#      76     def stix_dir(self, dir):
# ---> 77         self.stix_dir = dir
#      78
#      79     def get(self, stix_id, _composite_filters=None):
#
# RuntimeError: maximum recursion depth exceeded while calling a Python object

# %% [markdown]
# Once you have an ``Environment`` you can store some STIX content in it with ``add()``:

# %%
from stix2 import Indicator

indicator = Indicator(id="indicator--01234567-89ab-cdef-0123-456789abcdef",
                      labels=["malicious-activity"],
                      pattern="[file:hashes.md5 = 'd41d8cd98f00b204e9800998ecf8427e']")
env.add(indicator)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-1926a8167416> in <module>()
#       4                       labels=["malicious-activity"],
#       5                       pattern="[file:hashes.md5 = 'd41d8cd98f00b204e9800998ecf8427e']")
# ----> 6 env.add(indicator)
#
# /home/lu/Projects/cti-python-stix2/stix2/environment.pyc in add(self, *args, **kwargs)
#     147     def add(self, *args, **kwargs):
#     148         try:
# --> 149             return self.sink.add(*args, **kwargs)
#     150         except AttributeError:
#     151             raise AttributeError('Environment has no data sink to put objects in')
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/memory.pyc in add(self, stix_data)
#      96         """
#      97         """
# ---> 98         _add(self, stix_data)
#      99
#     100     def save_to_file(self, file_path):
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/memory.pyc in _add(store, stix_data)
#      35         # stix objects are in a bundle
#      36         # make dictionary of the objects for easy lookup
# ---> 37         for stix_obj in stix_data["objects"]:
#      38             store.data[stix_obj["id"]] = stix_obj
#      39     elif isinstance(stix_data, list):
#
# /home/lu/Projects/cti-python-stix2/stix2/base.pyc in __getitem__(self, key)
#     126
#     127     def __getitem__(self, key):
# --> 128         return self._inner[key]
#     129
#     130     def __iter__(self):
#
# KeyError: 'objects'

# %% [markdown]
# You can retrieve STIX objects from the DataSources in the Environment with ``get()``, ``query()``, and ``all_versions()``, just as you would for a DataSource.

# %%
print(env.get("indicator--01234567-89ab-cdef-0123-456789abcdef"))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-8cc9a41fe489> in <module>()
# ----> 1 print(env.get("indicator--01234567-89ab-cdef-0123-456789abcdef"))
#
# /home/lu/Projects/cti-python-stix2/stix2/environment.pyc in get(self, *args, **kwargs)
#     108     def get(self, *args, **kwargs):
#     109         try:
# --> 110             return self.source.get(*args, **kwargs)
#     111         except AttributeError:
#     112             raise AttributeError('Environment has no data source to query')
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/__init__.pyc in get(self, stix_id, _composite_filters)
#     381         # for every configured Data Source, call its retrieve handler
#     382         for ds_id, ds in iteritems(self.data_sources):
# --> 383             data = ds.get(stix_id=stix_id, _composite_filters=list(self.filters))
#     384             all_data.append(data)
#     385
#
# /home/lu/Projects/cti-python-stix2/stix2/sources/memory.pyc in get(self, stix_id, _composite_filters)
#     141
#     142         # reduce to most recent version
# --> 143         stix_obj = sorted(all_data, key=lambda k: k['modified'])[0]
#     144
#     145         return stix_obj
#
# IndexError: list index out of range

# %% [markdown]
# ### Creating STIX Objects With Defaults
#
# To create STIX objects with default values for certain properties, use an ``ObjectFactory``. For instance, say we want all objects we create to have a ``created_by_ref`` property pointing to the ``Identity`` object representing our organization.

# %%
from stix2 import Indicator, ObjectFactory

factory = ObjectFactory(created_by_ref="identity--311b2d2d-f010-5473-83ec-1edf84858f4c")

# %% [markdown]
# Once you've set up the Object Factory, use its ``create()`` method, passing in the class for the type of object you wish to create, followed by the other properties and their values for the object.

# %%
ind = factory.create(Indicator,
                     labels=["malicious-activity"],
                     pattern="[file:hashes.md5 = 'd41d8cd98f00b204e9800998ecf8427e']")
print(ind)
# Out:
# {
#     "type": "indicator",
#     "id": "indicator--8e7c5051-1ebb-467a-a22c-775e0e7a6658",
#     "created_by_ref": "identity--311b2d2d-f010-5473-83ec-1edf84858f4c",
#     "created": "2017-09-25T20:27:00.267Z",
#     "modified": "2017-09-25T20:27:00.267Z",
#     "labels": [
#         "malicious-activity"
#     ],
#     "pattern": "[file:hashes.md5 = 'd41d8cd98f00b204e9800998ecf8427e']",
#     "valid_from": "2017-09-25T20:27:00.267261Z"
# }

# %% [markdown]
# All objects we create with that ``ObjectFactory`` will automatically get the default value for ``created_by_ref``. These are the properties for which defaults can be set:
#
# - ``created_by_ref``
# - ``created``
# - ``external_references``
# - ``object_marking_refs``
#
# These defaults can be bypassed. For example, say you have an ``Environment`` with multiple default values but want to create an object with a different value for ``created_by_ref``, or none at all.

# %%
factory2 = ObjectFactory(created_by_ref="identity--311b2d2d-f010-5473-83ec-1edf84858f4c",
                         created="2017-09-25T18:07:46.255472Z")
env2 = Environment(factory=factory2)

ind2 = env2.create(Indicator,
                   created_by_ref=None,
                   labels=["malicious-activity"],
                   pattern="[file:hashes.md5 = 'd41d8cd98f00b204e9800998ecf8427e']")
print(ind2)
# Out:
# {
#     "type": "indicator",
#     "id": "indicator--1959a776-5679-4f0e-b20e-d4526912a13d",
#     "created": "2017-09-25T18:07:46.255Z",
#     "modified": "2017-09-25T18:07:46.255Z",
#     "labels": [
#         "malicious-activity"
#     ],
#     "pattern": "[file:hashes.md5 = 'd41d8cd98f00b204e9800998ecf8427e']",
#     "valid_from": "2017-09-25T20:34:58.317648Z"
# }

# %%
ind3 = env2.create(Indicator,
                       created_by_ref="identity--962cabe5-f7f3-438a-9169-585a8c971d12",
                       labels=["malicious-activity"],
                       pattern="[file:hashes.md5 = 'd41d8cd98f00b204e9800998ecf8427e']")
print(ind3)
# Out:
# {
#     "type": "indicator",
#     "id": "indicator--640dd598-983b-4644-8136-ca6f1e36ae33",
#     "created_by_ref": "identity--962cabe5-f7f3-438a-9169-585a8c971d12",
#     "created": "2017-09-25T18:07:46.255Z",
#     "modified": "2017-09-25T18:07:46.255Z",
#     "labels": [
#         "malicious-activity"
#     ],
#     "pattern": "[file:hashes.md5 = 'd41d8cd98f00b204e9800998ecf8427e']",
#     "valid_from": "2017-09-25T20:35:22.338315Z"
# }

# %% [markdown]
# For the full power of the Environment layer, create an Environment with both a DataStore/Source/Sink and an Object Factory:

# %%
environ = Environment(ObjectFactory(created_by_ref="identity--311b2d2d-f010-5473-83ec-1edf84858f4c"),
                      MemoryStore())

i = environ.create(Indicator,
                   labels=["malicious-activity"],
                   pattern="[file:hashes.md5 = 'd41d8cd98f00b204e9800998ecf8427e']")
environ.add(i)
print(environ.get(i.id))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-dbe0e1a10d8c> in <module>()
#       1 environ = Environment(ObjectFactory(created_by_ref="identity--311b2d2d-f010-5473-83ec-1edf84858f4c"),
#       2                       MemoryStore())
# ----> 3 with environ as env:
#       4     i = env.create(Indicator,
#       5                    labels=["malicious-activity"],
#
# AttributeError: __exit__
